# %%
import io
import requests
import FinanceDataReader as fdr
import pandas as pd
pd.options.plotting.backend = 'plotly'

# %%
start_yr = '2019'
kr_kp = fdr.DataReader('KS11'  , start_yr)
us_nd = fdr.DataReader('IXIC'  , start_yr)
jp_nk = fdr.DataReader('JP225' , start_yr)
ch_cs = fdr.DataReader('CSI300', start_yr)
uk_ft = fdr.DataReader('FTSE'  , start_yr)
gm_dx = fdr.DataReader('DAX'   , start_yr)
fr_cc = fdr.DataReader('CAC'   , start_yr)

# %%
kr_kp.plot()

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
content = requests.get(url).content
df = pd.read_csv(io.StringIO(content.decode('utf-8')))

# %%
df
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 269            NaN             Vietnam  14.058324  108.277199        0
# 270            NaN  West Bank and Gaza  31.952200   35.233200        0
# 271            NaN               Yemen  15.552727   48.516388        0
# 272            NaN              Zambia -13.133897   27.849332        0
# 273            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/14/21  2/15/21  \
# ...
